# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
import os

# Agrega la carpeta 'src' al path de python
base = r"D:\Proyectos\CPMP_TRANSFORMER\CPMP-Framework\CPMP-Framework"
sys.path.insert(0, os.path.join(base, "src"))

from models.cpmp_transformer_v9 import CPMPTransformer
from training.training import load_model

model_name = "v9_new_gen_data"
model = load_model(CPMPTransformer, model_name)

# %%
from solvers.model import ModelSolver

instance_file = "benchmarks/data5-5-1.dat"
max_steps = 100
H = 7

solver = ModelSolver(model)
eval = solver.solve(instance_file, H, max_steps)

print(eval)
# Out:
# (True, 41)
# d:\Proyectos\CPMP_TRANSFORMER\CPMP-Framework\venv\Lib\site-packages\torch\nn\modules\transformer.py:531: UserWarning: The PyTorch API of nested tensors is in prototype stage and will change in the near future. We recommend specifying layout=torch.jagged when constructing a nested tensor, as this layout receives active development, has better operator coverage, and works with torch.compile. (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\pytorch\aten\src\ATen\NestedTensorImpl.cpp:182.)
#   output = torch._nested_tensor_from_mask(

# %%
from solvers.model import ModelSolver
from solvers.utils import summary

folder = "benchmarks"
max_steps = 50
H = 7

solver = ModelSolver(model)
solved, steps = solver.solve_from_folder(folder, H, max_steps)
summary(solved, steps)

print(steps)
# Out:
# Instancias resueltas: 29/40
# Promedio de pasos: 35.45
# [41, 50, 50, 32, 34, 50, 47, 27, 47, 43, 50, 49, 50, 35, 42, 50, 50, 42, 50, 34, 50, 50, 38, 29, 50, 30, 39, 50, 37, 32, 26, 26, 33, 41, 38, 29, 33, 30, 25, 19]

# %%
from solvers.FRG import FRGSolver
from solvers.utils import summary

folder = "benchmarks"
max_steps = 50
H = 7

solver = FRGSolver()
solved, steps = solver.solve_from_folder(folder, H, max_steps)
summary(solved, steps)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 9
#       6 H = 7
#       8 solver = FRGSolver()
# ----> 9 solved, steps = solver.solve_from_folder(folder, H, max_steps)
#      10 summary(solved, steps)
#
# File D:\Proyectos\CPMP_TRANSFORMER\CPMP-Framework\CPMP-Framework\src\solvers\solver.py:27, in Solver.solve_from_folder(self, folder, H, max_steps)
#      25 if not os.path.isfile(filepath):
#      26     continue
# ---> 27 solved, steps = self.solve_from_path(filepath, H, max_steps)
#      28 solved_arr.append(solved)
#      29 steps_arr.append(steps)
#
# File D:\Proyectos\CPMP_TRANSFORMER\CPMP-Framework\CPMP-Framework\src\solvers\FRG.py:39, in FRGSolver.solve_from_path(self, instance_path, H, max_steps)
#      36 else:
#      37     cmd = [FRG_PATH, str(H), filepath, "1.2", str(max_steps), "0", "--no-assignement", "2"]
# ---> 39 result = subprocess.run(cmd, check=True, text=True, capture_output=True)
#      41 output_str = result.stdout.split('\t')[0].strip()
#      42 if not output_str.isdigit():
#
# File D:\Python3119\Lib\subprocess.py:550, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     548 with Popen(*popenargs, **kwargs) as process:
#     549     try:
# --> 550         stdout, stderr = process.communicate(input, timeout=timeout)
#     551     except TimeoutExpired as exc:
#     552         process.kill()
#
# File D:\Python3119\Lib\subprocess.py:1209, in Popen.communicate(self, input, timeout)
#    1206     endtime = None
#    1208 try:
# -> 1209     stdout, stderr = self._communicate(input, endtime, timeout)
#    1210 except KeyboardInterrupt:
#    1211     # https://bugs.python.org/issue25942
#    1212     # See the detailed comment in .wait().
#    1213     if timeout is not None:
#
# File D:\Python3119\Lib\subprocess.py:1628, in Popen._communicate(self, input, endtime, orig_timeout)
#    1624 # Wait for the reader threads, or time out.  If we time out, the
#    1625 # threads remain reading and the fds left open in case the user
#    1626 # calls communicate again.
#    1627 if self.stdout is not None:
# -> 1628     self.stdout_thread.join(self._remaining_time(endtime))
#    1629     if self.stdout_thread.is_alive():
#    1630         raise TimeoutExpired(self.args, orig_timeout)
#
# File D:\Python3119\Lib\threading.py:1119, in Thread.join(self, timeout)
#    1116     raise RuntimeError("cannot join current thread")
#    1118 if timeout is None:
# -> 1119     self._wait_for_tstate_lock()
#    1120 else:
#    1121     # the behavior of a negative timeout isn't documented, but
#    1122     # historically .join(timeout=x) for x<0 has acted as if timeout=0
#    1123     self._wait_for_tstate_lock(timeout=max(timeout, 0))
#
# File D:\Python3119\Lib\threading.py:1139, in Thread._wait_for_tstate_lock(self, block, timeout)
#    1136     return
#    1138 try:
# -> 1139     if lock.acquire(block, timeout):
#    1140         lock.release()
#    1141         self._stop()
#
# KeyboardInterrupt:
