# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
import os

# Agrega la carpeta 'src' al path de python
sys.path.append(os.path.abspath("../src"))

from models.cpmp_transformer_v9 import CPMPTransformer
from training.training import load_model

model_name = "v9"
model = load_model(CPMPTransformer, model_name)

# %%
from solvers.model import ModelSolver

instance_file = "benchmarks/data5-5-1.dat"
max_steps = 100
H = 7

solver = ModelSolver(model)
eval = solver.solve(instance_file, H, max_steps)

print(eval)
# Out:
# (True, 40)
# d:\Proyectos\CPMP_TRANSFORMER\CPMP-Framework\CPMP-Framework\venv\Lib\site-packages\torch\nn\modules\transformer.py:531: UserWarning: The PyTorch API of nested tensors is in prototype stage and will change in the near future. We recommend specifying layout=torch.jagged when constructing a nested tensor, as this layout receives active development, has better operator coverage, and works with torch.compile. (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\pytorch\aten\src\ATen\NestedTensorImpl.cpp:182.)
#   output = torch._nested_tensor_from_mask(

# %%
from solvers.model import ModelSolver
from solvers.utils import summary

folder = "benchmarks"
max_steps = 50
H = 7

solver = ModelSolver(model)
solved, steps = solver.solve_from_folder(folder, H, max_steps)
summary(solved, steps)

print(steps)
# Out:
# Instancias resueltas: 40/40
# Promedio de pasos: 33.00
# [40, 35, 37, 28, 31, 46, 36, 30, 32, 35, 32, 40, 30, 32, 26, 28, 35, 32, 37, 43, 43, 41, 31, 26, 42, 32, 35, 44, 30, 31, 29, 27, 27, 27, 29, 32, 33, 34, 25, 17]

# %%
from solvers.FRG import FRGSolver
from solvers.utils import summary

folder = "benchmarks"
max_steps = 50
H = 7

solver = FRGSolver()
solved, steps = solver.solve_from_folder(folder, H, max_steps)
summary(solved, steps)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[4], line 9
#       6 H = 7
#       8 solver = FRGSolver()
# ----> 9 solved, steps = solver.solve_from_folder(folder, H, max_steps)
#      10 summary(solved, steps)
#
# File d:\Proyectos\CPMP_TRANSFORMER\CPMP-Framework\src\solvers\solver.py:23, in Solver.solve_from_folder(self, folder, H, max_steps)
#      21 for filename in os.listdir(INSTANCE_FOLDER / folder):
#      22     filepath = os.path.join(INSTANCE_FOLDER / folder, filename)
# ---> 23     solved, steps = self.solve_from_path(filepath, H, max_steps)
#      24     solved_arr.append(solved)
#      25     steps_arr.append(steps)
#
# File d:\Proyectos\CPMP_TRANSFORMER\CPMP-Framework\src\solvers\FRG.py:21, in FRGSolver.solve_from_path(self, instance_path, H, max_steps)
#      18 try:
#      19     self.lay2file(layout, filepath)
# ---> 21     result = subprocess.run(
#      22         [FRG_PATH, str(H), filepath, "1.2", str(max_steps), "0", "--no-assignement", "2"],
#      23         check=True,
#      24         text=True,
#      25         capture_output=True
#      26     )
#      28     output_str = result.stdout.split('\t')[0].strip()
#      29     if not output_str.isdigit():
#
# File D:\Python3119\Lib\subprocess.py:548, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     545     kwargs['stdout'] = PIPE
#     546     kwargs['stderr'] = PIPE
# --> 548 with Popen(*popenargs, **kwargs) as process:
#     549     try:
#     550         stdout, stderr = process.communicate(input, timeout=timeout)
#
# File D:\Python3119\Lib\subprocess.py:1026, in Popen.__init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask, pipesize, process_group)
#    1022         if self.text_mode:
#    1023             self.stderr = io.TextIOWrapper(self.stderr,
#    1024                     encoding=encoding, errors=errors)
# -> 1026     self._execute_child(args, executable, preexec_fn, close_fds,
#    1027                         pass_fds, cwd, env,
#    1028                         startupinfo, creationflags, shell,
#    1029                         p2cread, p2cwrite,
#    1030                         c2pread, c2pwrite,
#    1031                         errread, errwrite,
#    1032                         restore_signals,
#    1033                         gid, gids, uid, umask,
#    1034                         start_new_session, process_group)
#    1035 except:
#    1036     # Cleanup if the child failed starting.
#    1037     for f in filter(None, (self.stdin, self.stdout, self.stderr)):
#
# File D:\Python3119\Lib\subprocess.py:1538, in Popen._execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, unused_restore_signals, unused_gid, unused_gids, unused_uid, unused_umask, unused_start_new_session, unused_process_group)
#    1536 # Start the process
#    1537 try:
# -> 1538     hp, ht, pid, tid = _winapi.CreateProcess(executable, args,
#    1539                              # no special security
#    1540                              None, None,
#    1541                              int(not close_fds),
#    1542                              creationflags,
#    1543                              env,
#    1544                              cwd,
#    1545                              startupinfo)
#    1546 finally:
#    1547     # Child is launched. Close the parent's copy of those pipe
#    1548     # handles that only the child should have open.  You need
#    (...)   1551     # pipe will not close when the child process exits and the
#    1552     # ReadFile will hang.
#    1553     self._close_pipe_fds(p2cread, p2cwrite,
#    1554                          c2pread, c2pwrite,
#    1555                          errread, errwrite)
#
# OSError: [WinError 193] %1 no es una aplicación Win32 válida
