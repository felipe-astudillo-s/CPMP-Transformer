# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
import os

# Agrega la carpeta 'src' al path de python
sys.path.append(os.path.abspath("../src"))

from preprocessing.dataset import load_dataset

# %%
import sys
import os

# Agrega la carpeta 'src' al path de python
sys.path.append(os.path.abspath("../src"))

from preprocessing.dataset import load_dataset

filename = "E5-25.data"
data = load_dataset(filename)
# Out:
# Dataset E5-25.data cargado con 200000 muestras.

# %%
from models.cpmp_transformer_v7 import CPMPTransformer

H = 7
C_dim = 3
X_dim = 3
d_model = 64
nhead = 4
num_layers = 4
ff_dim_multiplier = 2
dropout = 0.3

model = CPMPTransformer(
    H=H,
    C_dim=C_dim,
    X_dim=X_dim,
    d_model=d_model,
    nhead=nhead,
    num_layers=num_layers,
    ff_dim_multiplier=ff_dim_multiplier,
    dropout=dropout
)

# %%
from training.training import train, Accuracy

epochs = 10
train_size = 160000 
test_size = 40000
batch_size = 128
learning_rate = 4e-4
weight_decay = 1e-3
patience = 10
metrics = [Accuracy()]
seed = 42

model = train(model, epochs, data, train_size, test_size, batch_size, learning_rate, weight_decay, patience, metrics, seed)
# Out:
# ℹ️ Usando dispositivo: cuda
#
# Epoch 1/10
#     Average - Train Loss: 2.2142 | Val Loss: 1.9509
#  | Accuracy: 51.62%
# Epoch 2/10
#     Average - Train Loss: 1.9801 | Val Loss: 1.8533
#  | Accuracy: 55.06%
# Epoch 3/10
#     Average - Train Loss: 1.9230 | Val Loss: 1.8156
#  | Accuracy: 56.45%
# Epoch 4/10
#     Average - Train Loss: 1.8879 | Val Loss: 1.7859
#  | Accuracy: 57.16%
# Epoch 5/10
#     Average - Train Loss: 1.8640 | Val Loss: 1.7600
#  | Accuracy: 57.99%
# Epoch 6/10
#     Average - Train Loss: 1.8435 | Val Loss: 1.7437
#  | Accuracy: 58.48%
# Epoch 7/10
#     Average - Train Loss: 1.8271 | Val Loss: 1.7295
#  | Accuracy: 58.89%
# Epoch 8/10
#     Average - Train Loss: 1.8177 | Val Loss: 1.7162
#  | Accuracy: 59.33%
# Epoch 9/10
#     Average - Train Loss: 1.8049 | Val Loss: 1.7157
#  | Accuracy: 59.63%
# Epoch 10/10
#     Average - Train Loss: 1.7969 | Val Loss: 1.7003
#  | Accuracy: 60.17%
# Mejor modelo (CrossEntropy): 1.7003 (Epoch 10)

# %%
from training.training import save_model

save_model(model, "v7")
# Out:
# ✅ Modelo guardado en d:\Proyectos\CPMP_TRANSFORMER\CPMP-Framework\models\v7.pth
