# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
import os

# Agrega la carpeta 'src' al path de python
sys.path.append(os.path.abspath("../src"))

from models.cpmp_transformer_v9 import CPMPTransformer
from training.training import load_model

model_name = "v9_dataBSG_250k"
model = load_model(CPMPTransformer, model_name)

# %%
from solvers.model import ModelSolver

instance_file = "benchmarks/data5-5-1.dat"
max_steps = 100
H = 7

solver = ModelSolver(model)
eval = solver.solve(instance_file, H, max_steps)

print(eval)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 8
#       5 H = 7
#       7 solver = ModelSolver(model)
# ----> 8 eval = solver.solve(instance_file, H, max_steps)
#      10 print(eval)
#
# File d:\Proyectos\CPMP_TRANSFORMER\CPMP-Framework\src\solvers\solver.py:11, in Solver.solve(self, instance_file, H, max_steps)
#       9 def solve(self, instance_file, H, max_steps):
#      10     instance_file = INSTANCE_FOLDER / instance_file
# ---> 11     return self.solve_from_path(instance_file, H, max_steps)
#
# File d:\Proyectos\CPMP_TRANSFORMER\CPMP-Framework\src\solvers\model.py:15, in ModelSolver.solve_from_path(self, instance_path, H, max_steps)
#      14 def solve_from_path(self, instance_path, H, max_steps):
# ---> 15     layout = read_file(instance_path, H)
#      16     S = len(layout.stacks)
#      18     # Conjunto para almacenar los estados visitados (como tuplas inmutables)
#
# File d:\Proyectos\CPMP_TRANSFORMER\CPMP-Framework\src\cpmp\layout.py:245, in read_file(file, H)
#     244 def read_file(file, H):
# --> 245     with open(file) as f:
#     246         S, C = [int(x) for x in next(f).split()] # read first line
#     247         stacks = []
#
# FileNotFoundError: [Errno 2] No such file or directory: 'd:\\Proyectos\\CPMP_TRANSFORMER\\CPMP-Framework\\instances\\benchmarks\\data5-5-1.dat'

# %%
from solvers.model import ModelSolver
from solvers.utils import summary

folder = "5-5"
max_steps = 50
H = 7

solver = ModelSolver(model)
solved, steps = solver.solve_from_folder(folder, H, max_steps)
summary(solved, steps)

print(steps)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 9
#       5 max_steps = 50
#       6 H = 7
#       7
#       8 solver = ModelSolver(model)
# ----> 9 solved, steps = solver.solve_from_folder(folder, H, max_steps)
#      10 summary(solved, steps)
#      11
#      12 print(steps)
#
# File /mnt/data/Proyectos/Universidad/CPMP-Transformer/src/solvers/solver.py:21, in Solver.solve_from_folder(self, folder, H, max_steps)
#      18 solved_arr = []
#      19 steps_arr = []
# ---> 21 for filename in os.listdir(INSTANCE_FOLDER / folder):
#      22     filepath = os.path.join(INSTANCE_FOLDER / folder, filename)
#      23     solved, steps = self.solve_from_path(filepath, H, max_steps)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/mnt/data/Proyectos/Universidad/CPMP-Transformer/instances/5-5'

# %%
from solvers.FRG import FRGSolver
from solvers.utils import summary

folder = "benchmarks"
max_steps = 50
H = 7

solver = FRGSolver()
solved, steps = solver.solve_from_folder(folder, H, max_steps)
summary(solved, steps)
# Out:
# ---------------------------------------------------------------------------
# IsADirectoryError                         Traceback (most recent call last)
# Cell In[3], line 9
#       5 max_steps = 50
#       6 H = 7
#       7
#       8 solver = FRGSolver()
# ----> 9 solved, steps = solver.solve_from_folder(folder, H, max_steps)
#      10 summary(solved, steps)
#
# File /mnt/data/Proyectos/Universidad/CPMP-Transformer/src/solvers/solver.py:23, in Solver.solve_from_folder(self, folder, H, max_steps)
#      21 for filename in os.listdir(INSTANCE_FOLDER / folder):
#      22     filepath = os.path.join(INSTANCE_FOLDER / folder, filename)
# ---> 23     solved, steps = self.solve_from_path(filepath, H, max_steps)
#      24     solved_arr.append(solved)
#      25     steps_arr.append(steps)
#
# File /mnt/data/Proyectos/Universidad/CPMP-Transformer/src/solvers/FRG.py:15, in FRGSolver.solve_from_path(self, instance_path, H, max_steps)
#      14 def solve_from_path(self, instance_path, H, max_steps):
# ---> 15     layout = read_file(instance_path, H)
#      16     pid = os.getpid()
#      17     filepath = INSTANCE_FOLDER / f"tmp_{pid}.txt"
#
# File /mnt/data/Proyectos/Universidad/CPMP-Transformer/src/cpmp/layout.py:245, in read_file(file, H)
#     244 def read_file(file, H):
# --> 245     with open(file) as f:
#     246         S, C = [int(x) for x in next(f).split()] # read first line
#     247         stacks = []
#
# IsADirectoryError: [Errno 21] Is a directory: '/mnt/data/Proyectos/Universidad/CPMP-Transformer/instances/benchmarks/CVS'
