# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
import os

# Agrega la carpeta 'src' al path de python
sys.path.append(os.path.abspath("../src"))

from preprocessing.dataset import load_dataset

# %%
import sys
import os

# Agrega la carpeta 'src' al path de python
sys.path.append(os.path.abspath("../src"))
from preprocessing.dataset import load_dataset


dataset_s3 = load_dataset("E4-15-H5_V9_BSG.data")
dataset_s4  = load_dataset("E5-25-H7_V9_BSG.data")
dataset_s5   = load_dataset("E6-45-H10_V9_BSG.data")
dataset_s6  = load_dataset("E7-30-H6_V9_BSG.data")
# Out:
# Dataset E4-15-H5_V9_BSG.data cargado con 49959 muestras.
# Dataset E5-25-H7_V9_BSG.data cargado con 99992 muestras.
# Dataset E6-45-H10_V9_BSG.data cargado con 49998 muestras.
# Dataset E7-30-H6_V9_BSG.data cargado con 49995 muestras.

# %%
from torch.utils.data import ConcatDataset

data = ConcatDataset([dataset_s3, dataset_s4, dataset_s5, dataset_s6])

print(f"Dataset combinado con un total de {len(data)} instancias.")
# Out:
# Dataset combinado con un total de 249944 instancias.

# %%
from models.cpmp_transformer_v9 import CPMPTransformer

H = 12
C_dim = 2
X_dim = 5
d_model = 64
nhead = 4
num_layers = 4
ff_dim_multiplier = 2
dropout = 0.3

model = CPMPTransformer(
    H=H,
    C_dim=C_dim,
    X_dim=X_dim,
    d_model=d_model,
    nhead=nhead,
    num_layers=num_layers,
    ff_dim_multiplier=ff_dim_multiplier,
    dropout=dropout
)

# %%
from training.training import train, Accuracy

epochs = 30
train_size = int(len(data) * 0.8) # 80% para entrenar, calculado dinámicamente
test_size = len(data) - train_size # 20% para test
batch_size = 128
learning_rate = 4e-4
weight_decay = 1e-3
patience = 10
metrics = [Accuracy()]
seed = 42

model = train(model, epochs, data, train_size, test_size, batch_size, learning_rate, weight_decay, patience, metrics, seed)
# Out:
# ℹ️ Usando dispositivo: cuda
#
# Epoch 1/30
#     Average - Train Loss: 2.3473 | Val Loss: 2.1654
#   | Accuracy: 55.27%
# Epoch 2/30
#     Average - Train Loss: 2.1756 | Val Loss: 2.0770
#   | Accuracy: 59.11%
# Epoch 3/30
#     Average - Train Loss: 2.1265 | Val Loss: 2.0375
#   | Accuracy: 60.49%
# Epoch 4/30
#     Average - Train Loss: 2.0978 | Val Loss: 2.0077
#   | Accuracy: 61.44%
# Epoch 5/30
#     Average - Train Loss: 2.0778 | Val Loss: 1.9888
#   | Accuracy: 62.26%
# Epoch 6/30
#     Average - Train Loss: 2.0621 | Val Loss: 1.9742
#   | Accuracy: 62.78%
# Epoch 7/30
#     Average - Train Loss: 2.0504 | Val Loss: 1.9611
#   | Accuracy: 63.10%
# Epoch 8/30
#     Average - Train Loss: 2.0404 | Val Loss: 1.9487
#   | Accuracy: 63.56%
# Epoch 9/30
#     Average - Train Loss: 2.0316 | Val Loss: 1.9379
#   | Accuracy: 63.84%
# Epoch 10/30
#     Average - Train Loss: 2.0242 | Val Loss: 1.9316
#   | Accuracy: 63.99%
# Epoch 11/30
#     Average - Train Loss: 2.0167 | Val Loss: 1.9199
#   | Accuracy: 64.30%
# Epoch 12/30
#     Average - Train Loss: 2.0110 | Val Loss: 1.9146
#   | Accuracy: 64.69%
# Epoch 13/30
#     Average - Train Loss: 2.0054 | Val Loss: 1.9176
#   | Accuracy: 64.61%
# Epoch 14/30
#     Average - Train Loss: 2.0003 | Val Loss: 1.9046
#   | Accuracy: 64.82%
# Epoch 15/30
#     Average - Train Loss: 1.9961 | Val Loss: 1.9061
#   | Accuracy: 64.63%
# Epoch 16/30
#     Average - Train Loss: 1.9905 | Val Loss: 1.8975
#   | Accuracy: 65.08%
# Epoch 17/30
#     Average - Train Loss: 1.9882 | Val Loss: 1.9008
#   | Accuracy: 65.05%
# Epoch 18/30
#     Average - Train Loss: 1.9827 | Val Loss: 1.9006
#   | Accuracy: 65.18%
# Epoch 19/30
#     Average - Train Loss: 1.9806 | Val Loss: 1.8873
#   | Accuracy: 65.30%
# Epoch 20/30
#     Average - Train Loss: 1.9788 | Val Loss: 1.8791
#   | Accuracy: 65.67%
# Epoch 21/30
#     Average - Train Loss: 1.9756 | Val Loss: 1.8849
#   | Accuracy: 65.52%
# Epoch 22/30
#     Average - Train Loss: 1.9729 | Val Loss: 1.8792
#   | Accuracy: 65.74%
# Epoch 23/30
#     Average - Train Loss: 1.9699 | Val Loss: 1.8758
#   | Accuracy: 65.88%
# Epoch 24/30
#     Average - Train Loss: 1.9660 | Val Loss: 1.8740
#   | Accuracy: 65.96%
# Epoch 25/30
#     Average - Train Loss: 1.9633 | Val Loss: 1.8816
#   | Accuracy: 65.63%
# Epoch 26/30
#     Average - Train Loss: 1.9616 | Val Loss: 1.8720
#   | Accuracy: 66.23%
# Epoch 27/30
#     Average - Train Loss: 1.9606 | Val Loss: 1.8655
#   | Accuracy: 66.12%
# Epoch 28/30
#     Average - Train Loss: 1.9576 | Val Loss: 1.8695
#   | Accuracy: 66.15%
# Epoch 29/30
#     Average - Train Loss: 1.9573 | Val Loss: 1.8633
#   | Accuracy: 66.32%
# Epoch 30/30
#     Average - Train Loss: 1.9548 | Val Loss: 1.8676
#   | Accuracy: 66.31%
# Mejor modelo (CrossEntropy): 1.8633 (Epoch 29)

# %%
from training.training import save_model

save_model(model, "v9_dataBSG_250k")
# Out:
# ✅ Modelo guardado en d:\Proyectos\CPMP_TRANSFORMER\CPMP-Framework\models\v9_dataBSG_250k.pth
