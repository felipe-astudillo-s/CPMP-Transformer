# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
import os

# Agrega la carpeta 'src' al path de python
sys.path.append(os.path.abspath("../src"))

from preprocessing.dataset import load_dataset

# %%
import sys
import os

# Agrega la carpeta 'src' al path de python
sys.path.append(os.path.abspath("../src"))
from preprocessing.dataset import load_dataset


dataset_s3 = load_dataset("E4-15-H5_V10.data")
dataset_s4  = load_dataset("E5-25-H7_V10.data")
dataset_s5   = load_dataset("E6-45-H10_V10.data")
dataset_s6  = load_dataset("E7-30-H6_V10.data")
# Out:
# Dataset E4-15-H5_V10.data cargado con 49905 muestras.
# Dataset E5-25-H7_V10.data cargado con 99992 muestras.
# Dataset E6-45-H10_V10.data cargado con 49993 muestras.
# Dataset E7-30-H6_V10.data cargado con 49997 muestras.

# %%
from torch.utils.data import ConcatDataset

data = ConcatDataset([dataset_s3, dataset_s4, dataset_s5, dataset_s6])

print(f"Dataset combinado con un total de {len(data)} instancias.")
# Out:
# Dataset combinado con un total de 249887 instancias.

# %%
from models.cpmp_transformer_v10 import CPMPTransformer

H = 12
C_dim = 2
X_dim = 5
d_model = 64
nhead = 4
num_layers = 4
ff_dim_multiplier = 2
dropout = 0.3

model = CPMPTransformer(
    H=H,
    C_dim=C_dim,
    X_dim=X_dim,
    d_model=d_model,
    nhead=nhead,
    num_layers=num_layers,
    ff_dim_multiplier=ff_dim_multiplier,
    dropout=dropout
)

# %%
from training.training import train, Accuracy

epochs = 30
train_size = int(len(data) * 0.8) # 80% para entrenar, calculado dinámicamente
test_size = len(data) - train_size # 20% para test
batch_size = 128
learning_rate = 4e-4
weight_decay = 1e-3
patience = 10
metrics = [Accuracy()]
seed = 42

model = train(model, epochs, data, train_size, test_size, batch_size, learning_rate, weight_decay, patience, metrics, seed)
# Out:
# ℹ️ Usando dispositivo: cuda
#
# Epoch 1/30
#     Average - Train Loss: 2.3687 | Val Loss: 2.2430
#   | Accuracy: 40.82%
# Epoch 2/30
#     Average - Train Loss: 2.2502 | Val Loss: 2.1748
#   | Accuracy: 43.51%
# Epoch 3/30
#     Average - Train Loss: 2.2080 | Val Loss: 2.1431
#   | Accuracy: 44.10%
# Epoch 4/30
#     Average - Train Loss: 2.1796 | Val Loss: 2.0983
#   | Accuracy: 46.40%
# Epoch 5/30
#     Average - Train Loss: 2.1589 | Val Loss: 2.0809
#   | Accuracy: 46.63%
# Epoch 6/30
#     Average - Train Loss: 2.1430 | Val Loss: 2.0527
#   | Accuracy: 47.89%
# Epoch 7/30
#     Average - Train Loss: 2.1292 | Val Loss: 2.0426
#   | Accuracy: 48.12%
# Epoch 8/30
#     Average - Train Loss: 2.1196 | Val Loss: 2.0276
#   | Accuracy: 48.83%
# Epoch 9/30
#     Average - Train Loss: 2.1089 | Val Loss: 2.0199
#   | Accuracy: 49.06%
# Epoch 10/30
#     Average - Train Loss: 2.1008 | Val Loss: 2.0147
#   | Accuracy: 49.01%
# Epoch 11/30
#     Average - Train Loss: 2.0947 | Val Loss: 2.0092
#   | Accuracy: 49.40%
# Epoch 12/30
#     Average - Train Loss: 2.0873 | Val Loss: 1.9984
#   | Accuracy: 49.80%
# Epoch 13/30
#     Average - Train Loss: 2.0817 | Val Loss: 1.9929
#   | Accuracy: 49.89%
# Epoch 14/30
#     Average - Train Loss: 2.0773 | Val Loss: 1.9881
#   | Accuracy: 50.00%
# Epoch 15/30
#     Average - Train Loss: 2.0724 | Val Loss: 1.9764
#   | Accuracy: 50.47%
# Epoch 16/30
#     Average - Train Loss: 2.0671 | Val Loss: 1.9720
#   | Accuracy: 50.58%
# Epoch 17/30
#     Average - Train Loss: 2.0634 | Val Loss: 1.9717
#   | Accuracy: 50.68%
# Epoch 18/30
#     Average - Train Loss: 2.0579 | Val Loss: 1.9662
#   | Accuracy: 50.61%
# Epoch 19/30
#     Average - Train Loss: 2.0548 | Val Loss: 1.9651
#   | Accuracy: 50.98%
# Epoch 20/30
#     Average - Train Loss: 2.0520 | Val Loss: 1.9659
#   | Accuracy: 50.99%
# Epoch 21/30
#     Average - Train Loss: 2.0488 | Val Loss: 1.9607
#   | Accuracy: 51.02%
# Epoch 22/30
#     Average - Train Loss: 2.0460 | Val Loss: 1.9514
#   | Accuracy: 51.31%
# Epoch 23/30
#     Average - Train Loss: 2.0425 | Val Loss: 1.9493
#   | Accuracy: 51.36%
# Epoch 24/30
#     Average - Train Loss: 2.0402 | Val Loss: 1.9450
#   | Accuracy: 51.65%
# Epoch 25/30
#     Average - Train Loss: 2.0371 | Val Loss: 1.9398
#   | Accuracy: 51.56%
# Epoch 26/30
#     Average - Train Loss: 2.0349 | Val Loss: 1.9416
#   | Accuracy: 51.70%
# Epoch 27/30
#     Average - Train Loss: 2.0318 | Val Loss: 1.9379
#   | Accuracy: 51.82%
# Epoch 28/30
#     Average - Train Loss: 2.0293 | Val Loss: 1.9373
#   | Accuracy: 51.70%
# Epoch 29/30
#     Average - Train Loss: 2.0282 | Val Loss: 1.9317
#   | Accuracy: 52.04%
# Epoch 30/30
#     Average - Train Loss: 2.0249 | Val Loss: 1.9314
#   | Accuracy: 52.14%
# Mejor modelo (CrossEntropy): 1.9314 (Epoch 30)

# %%
from training.training import save_model

save_model(model, "v10_data_fix_normalizada")
# Out:
# ✅ Modelo guardado en d:\Proyectos\CPMP_TRANSFORMER\CPMP-Framework\models\v10_data_fix_normalizada.pth
